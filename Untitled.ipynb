# %%
import pandas as pd
import numpy as np
missing_values = ["배달전문업체","심부름"]#
df = pd.read_csv("delivery.csv",na_values = missing_values)
df = df.filter(['DLVR_STORE_INDUTY_NM','DLVR_STORE_SIDO'])
df_group = df.groupby(['DLVR_STORE_SIDO'])
for a,b in df_group:
    print(a)
    print(b)
# Out:
# 강원도
#         DLVR_STORE_INDUTY_NM DLVR_STORE_SIDO
# 1490                  카페/디저트             강원도
# 1738                  카페/디저트             강원도
# 1826                  카페/디저트             강원도
# 2520                  카페/디저트             강원도
# 2808                  카페/디저트             강원도
# ...                      ...             ...
# 5156902               카페/디저트             강원도
# 5156967               카페/디저트             강원도
# 5157213               카페/디저트             강원도
# 5157857               카페/디저트             강원도
# 5158191               카페/디저트             강원도
#
# [12703 rows x 2 columns]
# 경기도
#         DLVR_STORE_INDUTY_NM DLVR_STORE_SIDO
# 1                         찜탕             경기도
# 3                         한식             경기도
# 4                         한식             경기도
# 5                      족발/보쌈             경기도
# 7                         야식             경기도
# ...                      ...             ...
# 5158317                   분식             경기도
# ...

# %%
GDP = pd.read_csv('GDP_per_city.csv',encoding='cp949')
GDP=GDP.filter(['행정구역','2017 p).2'])
GDP
# Out:
#        행정구역  2017 p).2
# 0     서울특별시      21429
# 1     부산광역시      18332
# 2     대구광역시      17568
# 3     인천광역시      17550
# 4     광주광역시      17343
# 5     대전광역시      18454
# 6       경기도      18580
# 7       강원도      16583
# 8      충청북도      17030
# 9      충청남도      17613
# 10     전라북도      16848
# 11     전라남도      15938
# 12     경상북도      16504
# 13     경상남도      16864
# 14  제주특별자치도      17464

# %%
pcc= pd.read_csv('people_count_per_city.csv',encoding='cp949')
pcc=pcc.filter(['인구'])
pcc
# Out:
#           인구
# 0    9708247
# 1    3401072
# 2    2428228
# 3    2943491
# 4    1454154
# 5    1469431
# 6   13370714
# 7    1540689
# 8    1598162
# 9    2120519
# 10   1807094
# 11   1851985
# 12   2640932
# 13   3345169
# 14    672524

# %%
GDP_PCC=pd.concat([GDP,pcc],axis=1)
GDP_PCC
# Out:
#        행정구역  2017 p).2        인구
# 0     서울특별시      21429   9708247
# 1     부산광역시      18332   3401072
# 2     대구광역시      17568   2428228
# 3     인천광역시      17550   2943491
# 4     광주광역시      17343   1454154
# 5     대전광역시      18454   1469431
# 6       경기도      18580  13370714
# 7       강원도      16583   1540689
# 8      충청북도      17030   1598162
# 9      충청남도      17613   2120519
# 10     전라북도      16848   1807094
# 11     전라남도      15938   1851985
# 12     경상북도      16504   2640932
# 13     경상남도      16864   3345169
# 14  제주특별자치도      17464    672524

# %%
import matplotlib.pylab as plt

# %%
df['DLVR_STORE_INDUTY_NM'].unique()
# Out:
# array(['치킨', '찜탕', '한식', '족발/보쌈', '분식', '야식', '돈까스/일식', '회', '피자', '중식',
#        '카페/디저트', nan, '패스트푸드', '아시안/양식', '도시락'], dtype=object)
